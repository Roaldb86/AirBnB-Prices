# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Questions:
#
#  - How to achieve the best price on AirBNB?
#  - How to achieve good reviews
#  -

# %%
print("Size of dataframes, rows, columns \n", 
      "Calendar : ", calendar.shape, "\n",
      "Listings : ", listings.shape, "\n",
      "Reviews : ", reviews.shape,)
# Out:
# Size of dataframes, rows, columns
#  Calendar :  (1393570, 4)
#  Listings :  (3818, 92)
#  Reviews :  (84849, 6)

# %%
# Import data into dataframes
calendar = pd.read_csv("./seattle/calendar.csv")
listings = pd.read_csv("./seattle/listings.csv")
reviews = pd.read_csv("./seattle/reviews.csv")

# %%
listings.info()

# %%
# List comprehensions for headers and corresponding missing values where series has missing values
missing = [listings[series].isnull().sum() for series in list(listings) if listings[series].isnull().sum() != 0]
headers_missing = [series for series in list(listings) if listings[series].isnull().sum() != 0]

fig = plt.pyplot.subplots(figsize=(15,10))
plt.pyplot.title("Missing values for each column")
plt.pyplot.xlabel("Columns")
plt.pyplot.ylabel("Missing values")
plt.pyplot.bar(headers_missing, missing)
plt.pyplot.xticks(rotation=90);

# %%
plt.pyplot.figure(figsize=(15,10))
sns.heatmap(listings.isnull(), cbar=False, yticklabels=False);

# %%
plt.pyplot.hist(listings.columns[listings.isnull().sum()])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-b5030843e5b1> in <module>()
# ----> 1 plt.pyplot.hist(listings.columns[listings.isnull().sum()])
#
# C:\anaconda\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    2093
#    2094         key = com._values_from_object(key)
# -> 2095         result = getitem(key)
#    2096         if not is_scalar(result):
#    2097             return promote(result)
#
# IndexError: index 177 is out of bounds for axis 1 with size 92

# %%
price = listings['price']
subset1 = listings.iloc[:, :30]
subset2 = listings.iloc[:, 30:60]
subset3 = listings.iloc[:, 60:]
subset1['price'] = price
subset2['price'] = price
subset3['price'] = price

# %%
fig, ax = plt.pyplot.subplots(figsize=(15,30))
plt.pyplot.subplot(2,1,1)
sns.heatmap(subset1.corr(), annot=True, fmt='.2f')

plt.pyplot.subplot(2,1,2)
sns.heatmap(subset2.corr(), annot=True, fmt='.2f');

# %%
sns.heatmap(subset2.corr(), annot=True, fmt='.2f')

;
# Out:
# ''

# %%
sns.heatmap(subset3.corr(), annot=True, fmt='.2f')

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
# id                                  3818 non-null int64
# listing_url                         3818 non-null object
# scrape_id                           3818 non-null int64
# last_scraped                        3818 non-null object
# name                                3818 non-null object
# summary                             3641 non-null object
# space                               3249 non-null object
# description                         3818 non-null object
# experiences_offered                 3818 non-null object
# neighborhood_overview               2786 non-null object
# notes                               2212 non-null object
# transit                             2884 non-null object
# thumbnail_url                       3498 non-null object
# medium_url                          3498 non-null object
# picture_url                         3818 non-null object
# ...
